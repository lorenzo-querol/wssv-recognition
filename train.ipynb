# %% [markdown]
# # Import Libraries

# %%
import os
import shutil

os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"

import tensorflow as tf

import numpy as np

from sklearn.model_selection import StratifiedKFold
from sklearn.utils.class_weight import compute_class_weight

from utils import create_model, augment_images, flatten_datasets, fine_tune
from config import config, models

# %% [markdown]
# # Prepare Training Data
#
# Our data will be split into 80% training, and holding out 20% for testing later on. The training set we will be used for 5-fold cross validation during model fitting, so our training set will be further split into training and validation.

# %%
data_dir = "dataset/2-cropped"

train_set, test_set = tf.keras.utils.image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    seed=config["seed_value"],
    image_size=config["img_shape"],
    batch_size=config["batch_size"],
    label_mode="categorical",
    subset="both",
)

train_images, train_labels = flatten_datasets(train_set)
# Out:
# Found 447 files belonging to 2 classes.
# Using 358 files for training.
# Using 89 files for validation.

# %% [markdown]
# # Defining the Base Model
#
# This project will be using MobileNetV3-Small (1) and EfficientNetV2-B0 (2). We can easily get this from the TensorFlow API. Let's set a `flag` variable so we can easily set which model we want to test with.

# %%
flag = 3
base_model = models[flag]["base_model"]
model_name = models[flag]["model_name"]
num_layers_to_freeze = models[flag]["num_layers_to_freeze"]

# %%
for i, layer in enumerate(base_model.layers):
    print(i, layer.name)
# Out:
# 0 input_3
# 1 rescaling_2
# 2 Conv
# 3 Conv/BatchNorm
# 4 tf.__operators__.add_27
# 5 re_lu_32
# 6 tf.math.multiply_27
# 7 multiply_18
# 8 expanded_conv/depthwise
# 9 expanded_conv/depthwise/BatchNorm
# 10 re_lu_33
# 11 expanded_conv/project
# 12 expanded_conv/project/BatchNorm
# 13 expanded_conv/Add
# 14 expanded_conv_1/expand
# 15 expanded_conv_1/expand/BatchNorm
# 16 re_lu_34
# 17 expanded_conv_1/depthwise/pad
# 18 expanded_conv_1/depthwise
# 19 expanded_conv_1/depthwise/BatchNorm
# 20 re_lu_35
# 21 expanded_conv_1/project
# 22 expanded_conv_1/project/BatchNorm
# 23 expanded_conv_2/expand
# 24 expanded_conv_2/expand/BatchNorm
# 25 re_lu_36
# 26 expanded_conv_2/depthwise
# 27 expanded_conv_2/depthwise/BatchNorm
# 28 re_lu_37
# 29 expanded_conv_2/project
# 30 expanded_conv_2/project/BatchNorm
# 31 expanded_conv_2/Add
# 32 expanded_conv_3/expand
# 33 expanded_conv_3/expand/BatchNorm
# 34 re_lu_38
# 35 expanded_conv_3/depthwise/pad
# 36 expanded_conv_3/depthwise
# 37 expanded_conv_3/depthwise/BatchNorm
# 38 re_lu_39
# 39 expanded_conv_3/squeeze_excite/AvgPool
# 40 expanded_conv_3/squeeze_excite/Conv
# 41 expanded_conv_3/squeeze_excite/Relu
# 42 expanded_conv_3/squeeze_excite/Conv_1
# 43 tf.__operators__.add_28
# 44 re_lu_40
# 45 tf.math.multiply_28
# 46 expanded_conv_3/squeeze_excite/Mul
# 47 expanded_conv_3/project
# 48 expanded_conv_3/project/BatchNorm
# 49 expanded_conv_4/expand
# 50 expanded_conv_4/expand/BatchNorm
# 51 re_lu_41
# 52 expanded_conv_4/depthwise
# 53 expanded_conv_4/depthwise/BatchNorm
# 54 re_lu_42
# 55 expanded_conv_4/squeeze_excite/AvgPool
# 56 expanded_conv_4/squeeze_excite/Conv
# 57 expanded_conv_4/squeeze_excite/Relu
# 58 expanded_conv_4/squeeze_excite/Conv_1
# 59 tf.__operators__.add_29
# 60 re_lu_43
# 61 tf.math.multiply_29
# 62 expanded_conv_4/squeeze_excite/Mul
# 63 expanded_conv_4/project
# 64 expanded_conv_4/project/BatchNorm
# 65 expanded_conv_4/Add
# 66 expanded_conv_5/expand
# 67 expanded_conv_5/expand/BatchNorm
# 68 re_lu_44
# 69 expanded_conv_5/depthwise
# 70 expanded_conv_5/depthwise/BatchNorm
# 71 re_lu_45
# 72 expanded_conv_5/squeeze_excite/AvgPool
# 73 expanded_conv_5/squeeze_excite/Conv
# 74 expanded_conv_5/squeeze_excite/Relu
# 75 expanded_conv_5/squeeze_excite/Conv_1
# 76 tf.__operators__.add_30
# 77 re_lu_46
# 78 tf.math.multiply_30
# 79 expanded_conv_5/squeeze_excite/Mul
# 80 expanded_conv_5/project
# 81 expanded_conv_5/project/BatchNorm
# 82 expanded_conv_5/Add
# 83 expanded_conv_6/expand
# 84 expanded_conv_6/expand/BatchNorm
# 85 tf.__operators__.add_31
# 86 re_lu_47
# 87 tf.math.multiply_31
# 88 multiply_19
# 89 expanded_conv_6/depthwise/pad
# 90 expanded_conv_6/depthwise
# 91 expanded_conv_6/depthwise/BatchNorm
# 92 tf.__operators__.add_32
# 93 re_lu_48
# 94 tf.math.multiply_32
# 95 multiply_20
# 96 expanded_conv_6/project
# 97 expanded_conv_6/project/BatchNorm
# 98 expanded_conv_7/expand
# 99 expanded_conv_7/expand/BatchNorm
# 100 tf.__operators__.add_33
# 101 re_lu_49
# 102 tf.math.multiply_33
# 103 multiply_21
# 104 expanded_conv_7/depthwise
# 105 expanded_conv_7/depthwise/BatchNorm
# 106 tf.__operators__.add_34
# 107 re_lu_50
# 108 tf.math.multiply_34
# 109 multiply_22
# 110 expanded_conv_7/project
# 111 expanded_conv_7/project/BatchNorm
# 112 expanded_conv_7/Add
# 113 expanded_conv_8/expand
# 114 expanded_conv_8/expand/BatchNorm
# 115 tf.__operators__.add_35
# 116 re_lu_51
# 117 tf.math.multiply_35
# 118 multiply_23
# 119 expanded_conv_8/depthwise
# 120 expanded_conv_8/depthwise/BatchNorm
# 121 tf.__operators__.add_36
# 122 re_lu_52
# 123 tf.math.multiply_36
# 124 multiply_24
# 125 expanded_conv_8/project
# 126 expanded_conv_8/project/BatchNorm
# 127 expanded_conv_8/Add
# 128 expanded_conv_9/expand
# 129 expanded_conv_9/expand/BatchNorm
# 130 tf.__operators__.add_37
# 131 re_lu_53
# 132 tf.math.multiply_37
# 133 multiply_25
# 134 expanded_conv_9/depthwise
# 135 expanded_conv_9/depthwise/BatchNorm
# 136 tf.__operators__.add_38
# 137 re_lu_54
# 138 tf.math.multiply_38
# 139 multiply_26
# 140 expanded_conv_9/project
# 141 expanded_conv_9/project/BatchNorm
# 142 expanded_conv_9/Add
# 143 expanded_conv_10/expand
# 144 expanded_conv_10/expand/BatchNorm
# 145 tf.__operators__.add_39
# 146 re_lu_55
# 147 tf.math.multiply_39
# 148 multiply_27
# 149 expanded_conv_10/depthwise
# 150 expanded_conv_10/depthwise/BatchNorm
# 151 tf.__operators__.add_40
# 152 re_lu_56
# 153 tf.math.multiply_40
# 154 multiply_28
# 155 expanded_conv_10/squeeze_excite/AvgPool
# 156 expanded_conv_10/squeeze_excite/Conv
# 157 expanded_conv_10/squeeze_excite/Relu
# 158 expanded_conv_10/squeeze_excite/Conv_1
# 159 tf.__operators__.add_41
# 160 re_lu_57
# 161 tf.math.multiply_41
# 162 expanded_conv_10/squeeze_excite/Mul
# 163 expanded_conv_10/project
# 164 expanded_conv_10/project/BatchNorm
# 165 expanded_conv_11/expand
# 166 expanded_conv_11/expand/BatchNorm
# 167 tf.__operators__.add_42
# 168 re_lu_58
# 169 tf.math.multiply_42
# 170 multiply_29
# 171 expanded_conv_11/depthwise
# 172 expanded_conv_11/depthwise/BatchNorm
# 173 tf.__operators__.add_43
# 174 re_lu_59
# 175 tf.math.multiply_43
# 176 multiply_30
# 177 expanded_conv_11/squeeze_excite/AvgPool
# 178 expanded_conv_11/squeeze_excite/Conv
# 179 expanded_conv_11/squeeze_excite/Relu
# 180 expanded_conv_11/squeeze_excite/Conv_1
# 181 tf.__operators__.add_44
# 182 re_lu_60
# 183 tf.math.multiply_44
# 184 expanded_conv_11/squeeze_excite/Mul
# 185 expanded_conv_11/project
# 186 expanded_conv_11/project/BatchNorm
# 187 expanded_conv_11/Add
# 188 expanded_conv_12/expand
# 189 expanded_conv_12/expand/BatchNorm
# 190 tf.__operators__.add_45
# 191 re_lu_61
# 192 tf.math.multiply_45
# 193 multiply_31
# 194 expanded_conv_12/depthwise/pad
# 195 expanded_conv_12/depthwise
# 196 expanded_conv_12/depthwise/BatchNorm
# 197 tf.__operators__.add_46
# 198 re_lu_62
# 199 tf.math.multiply_46
# 200 multiply_32
# 201 expanded_conv_12/squeeze_excite/AvgPool
# 202 expanded_conv_12/squeeze_excite/Conv
# 203 expanded_conv_12/squeeze_excite/Relu
# 204 expanded_conv_12/squeeze_excite/Conv_1
# 205 tf.__operators__.add_47
# 206 re_lu_63
# 207 tf.math.multiply_47
# 208 expanded_conv_12/squeeze_excite/Mul
# 209 expanded_conv_12/project
# 210 expanded_conv_12/project/BatchNorm
# 211 expanded_conv_13/expand
# 212 expanded_conv_13/expand/BatchNorm
# 213 tf.__operators__.add_48
# 214 re_lu_64
# 215 tf.math.multiply_48
# 216 multiply_33
# 217 expanded_conv_13/depthwise
# 218 expanded_conv_13/depthwise/BatchNorm
# 219 tf.__operators__.add_49
# 220 re_lu_65
# 221 tf.math.multiply_49
# 222 multiply_34
# 223 expanded_conv_13/squeeze_excite/AvgPool
# 224 expanded_conv_13/squeeze_excite/Conv
# 225 expanded_conv_13/squeeze_excite/Relu
# 226 expanded_conv_13/squeeze_excite/Conv_1
# 227 tf.__operators__.add_50
# 228 re_lu_66
# 229 tf.math.multiply_50
# 230 expanded_conv_13/squeeze_excite/Mul
# 231 expanded_conv_13/project
# 232 expanded_conv_13/project/BatchNorm
# 233 expanded_conv_13/Add
# 234 expanded_conv_14/expand
# 235 expanded_conv_14/expand/BatchNorm
# 236 tf.__operators__.add_51
# 237 re_lu_67
# 238 tf.math.multiply_51
# 239 multiply_35
# 240 expanded_conv_14/depthwise
# 241 expanded_conv_14/depthwise/BatchNorm
# 242 tf.__operators__.add_52
# 243 re_lu_68
# 244 tf.math.multiply_52
# 245 multiply_36
# 246 expanded_conv_14/squeeze_excite/AvgPool
# 247 expanded_conv_14/squeeze_excite/Conv
# 248 expanded_conv_14/squeeze_excite/Relu
# 249 expanded_conv_14/squeeze_excite/Conv_1
# 250 tf.__operators__.add_53
# 251 re_lu_69
# 252 tf.math.multiply_53
# 253 expanded_conv_14/squeeze_excite/Mul
# 254 expanded_conv_14/project
# 255 expanded_conv_14/project/BatchNorm
# 256 expanded_conv_14/Add
# 257 Conv_1
# 258 Conv_1/BatchNorm
# 259 tf.__operators__.add_54
# 260 re_lu_70
# 261 tf.math.multiply_54
# 262 multiply_37
# 263 avg_pool

# %% [markdown]
# # Fitting the Model
#
# We define our cross validation strategy as `StratifiedKFold` and set the splits to 5 to ensure that the distribution of image samples per split remains equal all throughout to counter class imbalance.

# %%
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=config["seed_value"])

# Loop over the dataset to create separate folds
for i, (train_idx, valid_idx) in enumerate(
    cv.split(train_images, np.argmax(train_labels, axis=1))
):
    print(f"Fold {i + 1}")

    # Create a new model instance
    model = fine_tune(base_model, config, num_layers_to_freeze)

    # Get the training and validation data
    X_train, y_train = train_images[train_idx], train_labels[train_idx]
    X_valid, y_valid = train_images[valid_idx], train_labels[valid_idx]

    # Augment ONLY training data
    X_train, y_train = augment_images(X_train, y_train, 5)

    # Compute weights
    weights = compute_class_weight(
        class_weight="balanced", classes=np.unique([0, 1]), y=y_train.argmax(axis=1)
    )
    weights = dict(zip(np.unique([0, 1]), weights))

    # Define checkpoint path and checkpoint callback
    path = f"checkpoints/{model_name}/fold_{i+1}"
    if os.path.exists(path):
        shutil.rmtree(path)
    os.makedirs(path)

    # Save the weights using the `checkpoint_path` format
    checkpoint_path = path + "/cp-{epoch:04d}.ckpt"
    model.save_weights(checkpoint_path.format(epoch=0))

    # Define filename for CSV log
    filename = f"results/{model_name}/fold_{i+1}.csv"

    # Define callbacks
    callbacks = [
        tf.keras.callbacks.ModelCheckpoint(
            filepath=checkpoint_path,
            monitor="val_loss",
            save_best_only=True,
            save_weights_only=True,
            verbose=1,
        ),
        tf.keras.callbacks.EarlyStopping(monitor="val_loss", mode="min", patience=10),
        tf.keras.callbacks.CSVLogger(filename, separator=",", append=False),
    ]

    # Fit the model on the train set and evaluate on the validation set
    model.fit(
        X_train,
        y_train,
        batch_size=config["batch_size"],
        epochs=config["epochs"],
        class_weight=weights,
        validation_data=(X_valid, y_valid),
        verbose=,
        callbacks=callbacks,
    )
# Out:
# Fold 1
# Epoch 1/200
#
# Epoch 1: val_loss improved from inf to 0.80579, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0001.ckpt
# 27/27 - 55s - loss: 0.8522 - precision: 0.4551 - recall: 0.4551 - f1_score: 0.5709 - false_negatives: 935.0000 - true_positives: 781.0000 - false_positives: 935.0000 - true_negatives: 781.0000 - val_loss: 0.8058 - val_precision: 0.3889 - val_recall: 0.3889 - val_f1_score: 0.5098 - val_false_negatives: 44.0000 - val_true_positives: 28.0000 - val_false_positives: 44.0000 - val_true_negatives: 28.0000 - 55s/epoch - 2s/step
# Epoch 2/200
#
# Epoch 2: val_loss improved from 0.80579 to 0.78828, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0002.ckpt
# 27/27 - 6s - loss: 0.8044 - precision: 0.4930 - recall: 0.4930 - f1_score: 0.6048 - false_negatives: 870.0000 - true_positives: 846.0000 - false_positives: 870.0000 - true_negatives: 846.0000 - val_loss: 0.7883 - val_precision: 0.3889 - val_recall: 0.3889 - val_f1_score: 0.5098 - val_false_negatives: 44.0000 - val_true_positives: 28.0000 - val_false_positives: 44.0000 - val_true_negatives: 28.0000 - 6s/epoch - 234ms/step
# Epoch 3/200
#
# Epoch 3: val_loss improved from 0.78828 to 0.77195, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0003.ckpt
# 27/27 - 6s - loss: 0.7723 - precision: 0.4942 - recall: 0.4942 - f1_score: 0.6056 - false_negatives: 868.0000 - true_positives: 848.0000 - false_positives: 868.0000 - true_negatives: 848.0000 - val_loss: 0.7720 - val_precision: 0.4028 - val_recall: 0.4028 - val_f1_score: 0.5240 - val_false_negatives: 43.0000 - val_true_positives: 29.0000 - val_false_positives: 43.0000 - val_true_negatives: 29.0000 - 6s/epoch - 236ms/step
# Epoch 4/200
#
# Epoch 4: val_loss improved from 0.77195 to 0.76120, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0004.ckpt
# 27/27 - 6s - loss: 0.7597 - precision: 0.5076 - recall: 0.5076 - f1_score: 0.6170 - false_negatives: 845.0000 - true_positives: 871.0000 - false_positives: 845.0000 - true_negatives: 871.0000 - val_loss: 0.7612 - val_precision: 0.4167 - val_recall: 0.4167 - val_f1_score: 0.5378 - val_false_negatives: 42.0000 - val_true_positives: 30.0000 - val_false_positives: 42.0000 - val_true_negatives: 30.0000 - 6s/epoch - 227ms/step
# Epoch 5/200
#
# Epoch 5: val_loss improved from 0.76120 to 0.73636, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0005.ckpt
# 27/27 - 6s - loss: 0.7340 - precision: 0.5251 - recall: 0.5251 - f1_score: 0.6314 - false_negatives: 815.0000 - true_positives: 901.0000 - false_positives: 815.0000 - true_negatives: 901.0000 - val_loss: 0.7364 - val_precision: 0.4861 - val_recall: 0.4861 - val_f1_score: 0.6031 - val_false_negatives: 37.0000 - val_true_positives: 35.0000 - val_false_positives: 37.0000 - val_true_negatives: 35.0000 - 6s/epoch - 232ms/step
# Epoch 6/200
#
# Epoch 6: val_loss improved from 0.73636 to 0.72323, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0006.ckpt
# 27/27 - 7s - loss: 0.6987 - precision: 0.5361 - recall: 0.5361 - f1_score: 0.6409 - false_negatives: 796.0000 - true_positives: 920.0000 - false_positives: 796.0000 - true_negatives: 920.0000 - val_loss: 0.7232 - val_precision: 0.5139 - val_recall: 0.5139 - val_f1_score: 0.6275 - val_false_negatives: 35.0000 - val_true_positives: 37.0000 - val_false_positives: 35.0000 - val_true_negatives: 37.0000 - 7s/epoch - 242ms/step
# Epoch 7/200
#
# Epoch 7: val_loss improved from 0.72323 to 0.70939, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0007.ckpt
# 27/27 - 6s - loss: 0.6838 - precision: 0.5583 - recall: 0.5583 - f1_score: 0.6587 - false_negatives: 758.0000 - true_positives: 958.0000 - false_positives: 758.0000 - true_negatives: 958.0000 - val_loss: 0.7094 - val_precision: 0.5278 - val_recall: 0.5278 - val_f1_score: 0.6394 - val_false_negatives: 34.0000 - val_true_positives: 38.0000 - val_false_positives: 34.0000 - val_true_negatives: 38.0000 - 6s/epoch - 234ms/step
# Epoch 8/200
#
# Epoch 8: val_loss improved from 0.70939 to 0.68485, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0008.ckpt
# 27/27 - 6s - loss: 0.6515 - precision: 0.5833 - recall: 0.5833 - f1_score: 0.6789 - false_negatives: 715.0000 - true_positives: 1001.0000 - false_positives: 715.0000 - true_negatives: 1001.0000 - val_loss: 0.6849 - val_precision: 0.5694 - val_recall: 0.5694 - val_f1_score: 0.6738 - val_false_negatives: 31.0000 - val_true_positives: 41.0000 - val_false_positives: 31.0000 - val_true_negatives: 41.0000 - 6s/epoch - 231ms/step
# Epoch 9/200
#
# Epoch 9: val_loss improved from 0.68485 to 0.67126, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0009.ckpt
# 27/27 - 6s - loss: 0.6429 - precision: 0.6148 - recall: 0.6148 - f1_score: 0.7042 - false_negatives: 661.0000 - true_positives: 1055.0000 - false_positives: 661.0000 - true_negatives: 1055.0000 - val_loss: 0.6713 - val_precision: 0.5833 - val_recall: 0.5833 - val_f1_score: 0.6849 - val_false_negatives: 30.0000 - val_true_positives: 42.0000 - val_false_positives: 30.0000 - val_true_negatives: 42.0000 - 6s/epoch - 230ms/step
# Epoch 10/200
#
# Epoch 10: val_loss improved from 0.67126 to 0.64720, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0010.ckpt
# 27/27 - 6s - loss: 0.6152 - precision: 0.6329 - recall: 0.6329 - f1_score: 0.7185 - false_negatives: 630.0000 - true_positives: 1086.0000 - false_positives: 630.0000 - true_negatives: 1086.0000 - val_loss: 0.6472 - val_precision: 0.6250 - val_recall: 0.6250 - val_f1_score: 0.7172 - val_false_negatives: 27.0000 - val_true_positives: 45.0000 - val_false_positives: 27.0000 - val_true_negatives: 45.0000 - 6s/epoch - 234ms/step
# Epoch 11/200
#
# Epoch 11: val_loss improved from 0.64720 to 0.62685, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0011.ckpt
# 27/27 - 6s - loss: 0.5974 - precision: 0.6533 - recall: 0.6533 - f1_score: 0.7342 - false_negatives: 595.0000 - true_positives: 1121.0000 - false_positives: 595.0000 - true_negatives: 1121.0000 - val_loss: 0.6268 - val_precision: 0.6250 - val_recall: 0.6250 - val_f1_score: 0.7172 - val_false_negatives: 27.0000 - val_true_positives: 45.0000 - val_false_positives: 27.0000 - val_true_negatives: 45.0000 - 6s/epoch - 237ms/step
# Epoch 12/200
#
# Epoch 12: val_loss improved from 0.62685 to 0.60898, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0012.ckpt
# 27/27 - 6s - loss: 0.5865 - precision: 0.6748 - recall: 0.6748 - f1_score: 0.7507 - false_negatives: 558.0000 - true_positives: 1158.0000 - false_positives: 558.0000 - true_negatives: 1158.0000 - val_loss: 0.6090 - val_precision: 0.6528 - val_recall: 0.6528 - val_f1_score: 0.7378 - val_false_negatives: 25.0000 - val_true_positives: 47.0000 - val_false_positives: 25.0000 - val_true_negatives: 47.0000 - 6s/epoch - 227ms/step
# Epoch 13/200
#
# Epoch 13: val_loss improved from 0.60898 to 0.59480, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0013.ckpt
# 27/27 - 6s - loss: 0.5776 - precision: 0.6964 - recall: 0.6964 - f1_score: 0.7669 - false_negatives: 521.0000 - true_positives: 1195.0000 - false_positives: 521.0000 - true_negatives: 1195.0000 - val_loss: 0.5948 - val_precision: 0.6528 - val_recall: 0.6528 - val_f1_score: 0.7378 - val_false_negatives: 25.0000 - val_true_positives: 47.0000 - val_false_positives: 25.0000 - val_true_negatives: 47.0000 - 6s/epoch - 225ms/step
# Epoch 14/200
#
# Epoch 14: val_loss improved from 0.59480 to 0.57221, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0014.ckpt
# 27/27 - 6s - loss: 0.5507 - precision: 0.7127 - recall: 0.7127 - f1_score: 0.7792 - false_negatives: 493.0000 - true_positives: 1223.0000 - false_positives: 493.0000 - true_negatives: 1223.0000 - val_loss: 0.5722 - val_precision: 0.6944 - val_recall: 0.6944 - val_f1_score: 0.7677 - val_false_negatives: 22.0000 - val_true_positives: 50.0000 - val_false_positives: 22.0000 - val_true_negatives: 50.0000 - 6s/epoch - 228ms/step
# Epoch 15/200
#
# Epoch 15: val_loss improved from 0.57221 to 0.55792, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0015.ckpt
# 27/27 - 6s - loss: 0.5445 - precision: 0.7378 - recall: 0.7378 - f1_score: 0.7974 - false_negatives: 450.0000 - true_positives: 1266.0000 - false_positives: 450.0000 - true_negatives: 1266.0000 - val_loss: 0.5579 - val_precision: 0.7222 - val_recall: 0.7222 - val_f1_score: 0.7870 - val_false_negatives: 20.0000 - val_true_positives: 52.0000 - val_false_positives: 20.0000 - val_true_negatives: 52.0000 - 6s/epoch - 228ms/step
# Epoch 16/200
#
# Epoch 16: val_loss improved from 0.55792 to 0.53489, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0016.ckpt
# 27/27 - 6s - loss: 0.5232 - precision: 0.7617 - recall: 0.7617 - f1_score: 0.8152 - false_negatives: 409.0000 - true_positives: 1307.0000 - false_positives: 409.0000 - true_negatives: 1307.0000 - val_loss: 0.5349 - val_precision: 0.7778 - val_recall: 0.7778 - val_f1_score: 0.8244 - val_false_negatives: 16.0000 - val_true_positives: 56.0000 - val_false_positives: 16.0000 - val_true_negatives: 56.0000 - 6s/epoch - 225ms/step
# Epoch 17/200
#
# Epoch 17: val_loss improved from 0.53489 to 0.52252, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0017.ckpt
# 27/27 - 6s - loss: 0.5111 - precision: 0.7733 - recall: 0.7733 - f1_score: 0.8236 - false_negatives: 389.0000 - true_positives: 1327.0000 - false_positives: 389.0000 - true_negatives: 1327.0000 - val_loss: 0.5225 - val_precision: 0.7778 - val_recall: 0.7778 - val_f1_score: 0.8244 - val_false_negatives: 16.0000 - val_true_positives: 56.0000 - val_false_positives: 16.0000 - val_true_negatives: 56.0000 - 6s/epoch - 235ms/step
# Epoch 18/200
#
# Epoch 18: val_loss improved from 0.52252 to 0.50767, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0018.ckpt
# 27/27 - 6s - loss: 0.4962 - precision: 0.7920 - recall: 0.7920 - f1_score: 0.8371 - false_negatives: 357.0000 - true_positives: 1359.0000 - false_positives: 357.0000 - true_negatives: 1359.0000 - val_loss: 0.5077 - val_precision: 0.7917 - val_recall: 0.7917 - val_f1_score: 0.8335 - val_false_negatives: 15.0000 - val_true_positives: 57.0000 - val_false_positives: 15.0000 - val_true_negatives: 57.0000 - 6s/epoch - 227ms/step
# Epoch 19/200
#
# Epoch 19: val_loss improved from 0.50767 to 0.48353, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0019.ckpt
# 27/27 - 6s - loss: 0.4809 - precision: 0.7990 - recall: 0.7990 - f1_score: 0.8422 - false_negatives: 345.0000 - true_positives: 1371.0000 - false_positives: 345.0000 - true_negatives: 1371.0000 - val_loss: 0.4835 - val_precision: 0.8333 - val_recall: 0.8333 - val_f1_score: 0.8607 - val_false_negatives: 12.0000 - val_true_positives: 60.0000 - val_false_positives: 12.0000 - val_true_negatives: 60.0000 - 6s/epoch - 227ms/step
# Epoch 20/200
#
# Epoch 20: val_loss improved from 0.48353 to 0.47230, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0020.ckpt
# 27/27 - 6s - loss: 0.4656 - precision: 0.8228 - recall: 0.8228 - f1_score: 0.8595 - false_negatives: 304.0000 - true_positives: 1412.0000 - false_positives: 304.0000 - true_negatives: 1412.0000 - val_loss: 0.4723 - val_precision: 0.8472 - val_recall: 0.8472 - val_f1_score: 0.8745 - val_false_negatives: 11.0000 - val_true_positives: 61.0000 - val_false_positives: 11.0000 - val_true_negatives: 61.0000 - 6s/epoch - 229ms/step
# Epoch 21/200
#
# Epoch 21: val_loss improved from 0.47230 to 0.45578, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0021.ckpt
# 27/27 - 6s - loss: 0.4522 - precision: 0.8275 - recall: 0.8275 - f1_score: 0.8629 - false_negatives: 296.0000 - true_positives: 1420.0000 - false_positives: 296.0000 - true_negatives: 1420.0000 - val_loss: 0.4558 - val_precision: 0.8472 - val_recall: 0.8472 - val_f1_score: 0.8745 - val_false_negatives: 11.0000 - val_true_positives: 61.0000 - val_false_positives: 11.0000 - val_true_negatives: 61.0000 - 6s/epoch - 235ms/step
# Epoch 22/200
#
# Epoch 22: val_loss improved from 0.45578 to 0.44056, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0022.ckpt
# 27/27 - 6s - loss: 0.4343 - precision: 0.8432 - recall: 0.8432 - f1_score: 0.8742 - false_negatives: 269.0000 - true_positives: 1447.0000 - false_positives: 269.0000 - true_negatives: 1447.0000 - val_loss: 0.4406 - val_precision: 0.8889 - val_recall: 0.8889 - val_f1_score: 0.9031 - val_false_negatives: 8.0000 - val_true_positives: 64.0000 - val_false_positives: 8.0000 - val_true_negatives: 64.0000 - 6s/epoch - 235ms/step
# Epoch 23/200
#
# Epoch 23: val_loss improved from 0.44056 to 0.42680, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0023.ckpt
# 27/27 - 6s - loss: 0.4205 - precision: 0.8444 - recall: 0.8444 - f1_score: 0.8754 - false_negatives: 267.0000 - true_positives: 1449.0000 - false_positives: 267.0000 - true_negatives: 1449.0000 - val_loss: 0.4268 - val_precision: 0.8889 - val_recall: 0.8889 - val_f1_score: 0.9031 - val_false_negatives: 8.0000 - val_true_positives: 64.0000 - val_false_positives: 8.0000 - val_true_negatives: 64.0000 - 6s/epoch - 234ms/step
# Epoch 24/200
#
# Epoch 24: val_loss improved from 0.42680 to 0.41011, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0024.ckpt
# 27/27 - 6s - loss: 0.4119 - precision: 0.8584 - recall: 0.8584 - f1_score: 0.8856 - false_negatives: 243.0000 - true_positives: 1473.0000 - false_positives: 243.0000 - true_negatives: 1473.0000 - val_loss: 0.4101 - val_precision: 0.8889 - val_recall: 0.8889 - val_f1_score: 0.9031 - val_false_negatives: 8.0000 - val_true_positives: 64.0000 - val_false_positives: 8.0000 - val_true_negatives: 64.0000 - 6s/epoch - 234ms/step
# Epoch 25/200
#
# Epoch 25: val_loss improved from 0.41011 to 0.38953, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0025.ckpt
# 27/27 - 6s - loss: 0.3934 - precision: 0.8718 - recall: 0.8718 - f1_score: 0.8953 - false_negatives: 220.0000 - true_positives: 1496.0000 - false_positives: 220.0000 - true_negatives: 1496.0000 - val_loss: 0.3895 - val_precision: 0.8889 - val_recall: 0.8889 - val_f1_score: 0.9031 - val_false_negatives: 8.0000 - val_true_positives: 64.0000 - val_false_positives: 8.0000 - val_true_negatives: 64.0000 - 6s/epoch - 233ms/step
# Epoch 26/200
#
# Epoch 26: val_loss improved from 0.38953 to 0.37933, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0026.ckpt
# 27/27 - 6s - loss: 0.3842 - precision: 0.8834 - recall: 0.8834 - f1_score: 0.9034 - false_negatives: 200.0000 - true_positives: 1516.0000 - false_positives: 200.0000 - true_negatives: 1516.0000 - val_loss: 0.3793 - val_precision: 0.8889 - val_recall: 0.8889 - val_f1_score: 0.9031 - val_false_negatives: 8.0000 - val_true_positives: 64.0000 - val_false_positives: 8.0000 - val_true_negatives: 64.0000 - 6s/epoch - 229ms/step
# Epoch 27/200
#
# Epoch 27: val_loss improved from 0.37933 to 0.36878, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0027.ckpt
# 27/27 - 6s - loss: 0.3774 - precision: 0.8875 - recall: 0.8875 - f1_score: 0.9061 - false_negatives: 193.0000 - true_positives: 1523.0000 - false_positives: 193.0000 - true_negatives: 1523.0000 - val_loss: 0.3688 - val_precision: 0.8889 - val_recall: 0.8889 - val_f1_score: 0.9031 - val_false_negatives: 8.0000 - val_true_positives: 64.0000 - val_false_positives: 8.0000 - val_true_negatives: 64.0000 - 6s/epoch - 228ms/step
# Epoch 28/200
#
# Epoch 28: val_loss improved from 0.36878 to 0.35372, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0028.ckpt
# 27/27 - 6s - loss: 0.3621 - precision: 0.8951 - recall: 0.8951 - f1_score: 0.9123 - false_negatives: 180.0000 - true_positives: 1536.0000 - false_positives: 180.0000 - true_negatives: 1536.0000 - val_loss: 0.3537 - val_precision: 0.9028 - val_recall: 0.9028 - val_f1_score: 0.9129 - val_false_negatives: 7.0000 - val_true_positives: 65.0000 - val_false_positives: 7.0000 - val_true_negatives: 65.0000 - 6s/epoch - 233ms/step
# Epoch 29/200
#
# Epoch 29: val_loss improved from 0.35372 to 0.34036, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0029.ckpt
# 27/27 - 6s - loss: 0.3423 - precision: 0.8998 - recall: 0.8998 - f1_score: 0.9160 - false_negatives: 172.0000 - true_positives: 1544.0000 - false_positives: 172.0000 - true_negatives: 1544.0000 - val_loss: 0.3404 - val_precision: 0.9028 - val_recall: 0.9028 - val_f1_score: 0.9129 - val_false_negatives: 7.0000 - val_true_positives: 65.0000 - val_false_positives: 7.0000 - val_true_negatives: 65.0000 - 6s/epoch - 234ms/step
# Epoch 30/200
#
# Epoch 30: val_loss improved from 0.34036 to 0.32660, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0030.ckpt
# 27/27 - 6s - loss: 0.3378 - precision: 0.9108 - recall: 0.9108 - f1_score: 0.9243 - false_negatives: 153.0000 - true_positives: 1563.0000 - false_positives: 153.0000 - true_negatives: 1563.0000 - val_loss: 0.3266 - val_precision: 0.9028 - val_recall: 0.9028 - val_f1_score: 0.9129 - val_false_negatives: 7.0000 - val_true_positives: 65.0000 - val_false_positives: 7.0000 - val_true_negatives: 65.0000 - 6s/epoch - 231ms/step
# Epoch 31/200
#
# Epoch 31: val_loss improved from 0.32660 to 0.31472, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0031.ckpt
# 27/27 - 6s - loss: 0.3280 - precision: 0.9138 - recall: 0.9138 - f1_score: 0.9266 - false_negatives: 148.0000 - true_positives: 1568.0000 - false_positives: 148.0000 - true_negatives: 1568.0000 - val_loss: 0.3147 - val_precision: 0.9028 - val_recall: 0.9028 - val_f1_score: 0.9129 - val_false_negatives: 7.0000 - val_true_positives: 65.0000 - val_false_positives: 7.0000 - val_true_negatives: 65.0000 - 6s/epoch - 231ms/step
# Epoch 32/200
#
# Epoch 32: val_loss improved from 0.31472 to 0.30235, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0032.ckpt
# 27/27 - 6s - loss: 0.3114 - precision: 0.9207 - recall: 0.9207 - f1_score: 0.9321 - false_negatives: 136.0000 - true_positives: 1580.0000 - false_positives: 136.0000 - true_negatives: 1580.0000 - val_loss: 0.3024 - val_precision: 0.9028 - val_recall: 0.9028 - val_f1_score: 0.9129 - val_false_negatives: 7.0000 - val_true_positives: 65.0000 - val_false_positives: 7.0000 - val_true_negatives: 65.0000 - 6s/epoch - 230ms/step
# Epoch 33/200
#
# Epoch 33: val_loss improved from 0.30235 to 0.29276, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0033.ckpt
# 27/27 - 6s - loss: 0.3065 - precision: 0.9196 - recall: 0.9196 - f1_score: 0.9309 - false_negatives: 138.0000 - true_positives: 1578.0000 - false_positives: 138.0000 - true_negatives: 1578.0000 - val_loss: 0.2928 - val_precision: 0.9028 - val_recall: 0.9028 - val_f1_score: 0.9129 - val_false_negatives: 7.0000 - val_true_positives: 65.0000 - val_false_positives: 7.0000 - val_true_negatives: 65.0000 - 6s/epoch - 231ms/step
# Epoch 34/200
#
# Epoch 34: val_loss improved from 0.29276 to 0.28426, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0034.ckpt
# 27/27 - 6s - loss: 0.2972 - precision: 0.9207 - recall: 0.9207 - f1_score: 0.9320 - false_negatives: 136.0000 - true_positives: 1580.0000 - false_positives: 136.0000 - true_negatives: 1580.0000 - val_loss: 0.2843 - val_precision: 0.9167 - val_recall: 0.9167 - val_f1_score: 0.9273 - val_false_negatives: 6.0000 - val_true_positives: 66.0000 - val_false_positives: 6.0000 - val_true_negatives: 66.0000 - 6s/epoch - 232ms/step
# Epoch 35/200
#
# Epoch 35: val_loss improved from 0.28426 to 0.27515, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0035.ckpt
# 27/27 - 6s - loss: 0.2851 - precision: 0.9213 - recall: 0.9213 - f1_score: 0.9320 - false_negatives: 135.0000 - true_positives: 1581.0000 - false_positives: 135.0000 - true_negatives: 1581.0000 - val_loss: 0.2751 - val_precision: 0.9167 - val_recall: 0.9167 - val_f1_score: 0.9273 - val_false_negatives: 6.0000 - val_true_positives: 66.0000 - val_false_positives: 6.0000 - val_true_negatives: 66.0000 - 6s/epoch - 232ms/step
# Epoch 36/200
#
# Epoch 36: val_loss improved from 0.27515 to 0.26313, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0036.ckpt
# 27/27 - 6s - loss: 0.2751 - precision: 0.9225 - recall: 0.9225 - f1_score: 0.9335 - false_negatives: 133.0000 - true_positives: 1583.0000 - false_positives: 133.0000 - true_negatives: 1583.0000 - val_loss: 0.2631 - val_precision: 0.9167 - val_recall: 0.9167 - val_f1_score: 0.9273 - val_false_negatives: 6.0000 - val_true_positives: 66.0000 - val_false_positives: 6.0000 - val_true_negatives: 66.0000 - 6s/epoch - 231ms/step
# Epoch 37/200
#
# Epoch 37: val_loss improved from 0.26313 to 0.25533, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0037.ckpt
# 27/27 - 6s - loss: 0.2674 - precision: 0.9266 - recall: 0.9266 - f1_score: 0.9367 - false_negatives: 126.0000 - true_positives: 1590.0000 - false_positives: 126.0000 - true_negatives: 1590.0000 - val_loss: 0.2553 - val_precision: 0.9167 - val_recall: 0.9167 - val_f1_score: 0.9273 - val_false_negatives: 6.0000 - val_true_positives: 66.0000 - val_false_positives: 6.0000 - val_true_negatives: 66.0000 - 6s/epoch - 227ms/step
# Epoch 38/200
#
# Epoch 38: val_loss improved from 0.25533 to 0.24740, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0038.ckpt
# 27/27 - 6s - loss: 0.2561 - precision: 0.9376 - recall: 0.9376 - f1_score: 0.9453 - false_negatives: 107.0000 - true_positives: 1609.0000 - false_positives: 107.0000 - true_negatives: 1609.0000 - val_loss: 0.2474 - val_precision: 0.9167 - val_recall: 0.9167 - val_f1_score: 0.9273 - val_false_negatives: 6.0000 - val_true_positives: 66.0000 - val_false_positives: 6.0000 - val_true_negatives: 66.0000 - 6s/epoch - 235ms/step
# Epoch 39/200
#
# Epoch 39: val_loss improved from 0.24740 to 0.23570, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0039.ckpt
# 27/27 - 6s - loss: 0.2429 - precision: 0.9347 - recall: 0.9347 - f1_score: 0.9431 - false_negatives: 112.0000 - true_positives: 1604.0000 - false_positives: 112.0000 - true_negatives: 1604.0000 - val_loss: 0.2357 - val_precision: 0.9167 - val_recall: 0.9167 - val_f1_score: 0.9273 - val_false_negatives: 6.0000 - val_true_positives: 66.0000 - val_false_positives: 6.0000 - val_true_negatives: 66.0000 - 6s/epoch - 225ms/step
# Epoch 40/200
#
# Epoch 40: val_loss improved from 0.23570 to 0.22884, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0040.ckpt
# 27/27 - 6s - loss: 0.2333 - precision: 0.9481 - recall: 0.9481 - f1_score: 0.9539 - false_negatives: 89.0000 - true_positives: 1627.0000 - false_positives: 89.0000 - true_negatives: 1627.0000 - val_loss: 0.2288 - val_precision: 0.9167 - val_recall: 0.9167 - val_f1_score: 0.9273 - val_false_negatives: 6.0000 - val_true_positives: 66.0000 - val_false_positives: 6.0000 - val_true_negatives: 66.0000 - 6s/epoch - 226ms/step
# Epoch 41/200
#
# Epoch 41: val_loss improved from 0.22884 to 0.22145, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0041.ckpt
# 27/27 - 6s - loss: 0.2254 - precision: 0.9499 - recall: 0.9499 - f1_score: 0.9553 - false_negatives: 86.0000 - true_positives: 1630.0000 - false_positives: 86.0000 - true_negatives: 1630.0000 - val_loss: 0.2214 - val_precision: 0.9167 - val_recall: 0.9167 - val_f1_score: 0.9273 - val_false_negatives: 6.0000 - val_true_positives: 66.0000 - val_false_positives: 6.0000 - val_true_negatives: 66.0000 - 6s/epoch - 226ms/step
# Epoch 42/200
#
# Epoch 42: val_loss improved from 0.22145 to 0.21384, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0042.ckpt
# 27/27 - 6s - loss: 0.2134 - precision: 0.9493 - recall: 0.9493 - f1_score: 0.9547 - false_negatives: 87.0000 - true_positives: 1629.0000 - false_positives: 87.0000 - true_negatives: 1629.0000 - val_loss: 0.2138 - val_precision: 0.9167 - val_recall: 0.9167 - val_f1_score: 0.9273 - val_false_negatives: 6.0000 - val_true_positives: 66.0000 - val_false_positives: 6.0000 - val_true_negatives: 66.0000 - 6s/epoch - 229ms/step
# Epoch 43/200
#
# Epoch 43: val_loss improved from 0.21384 to 0.20616, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0043.ckpt
# 27/27 - 6s - loss: 0.2038 - precision: 0.9551 - recall: 0.9551 - f1_score: 0.9595 - false_negatives: 77.0000 - true_positives: 1639.0000 - false_positives: 77.0000 - true_negatives: 1639.0000 - val_loss: 0.2062 - val_precision: 0.9306 - val_recall: 0.9306 - val_f1_score: 0.9378 - val_false_negatives: 5.0000 - val_true_positives: 67.0000 - val_false_positives: 5.0000 - val_true_negatives: 67.0000 - 6s/epoch - 229ms/step
# Epoch 44/200
#
# Epoch 44: val_loss improved from 0.20616 to 0.20105, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0044.ckpt
# 27/27 - 6s - loss: 0.2100 - precision: 0.9528 - recall: 0.9528 - f1_score: 0.9577 - false_negatives: 81.0000 - true_positives: 1635.0000 - false_positives: 81.0000 - true_negatives: 1635.0000 - val_loss: 0.2011 - val_precision: 0.9306 - val_recall: 0.9306 - val_f1_score: 0.9378 - val_false_negatives: 5.0000 - val_true_positives: 67.0000 - val_false_positives: 5.0000 - val_true_negatives: 67.0000 - 6s/epoch - 229ms/step
# Epoch 45/200
#
# Epoch 45: val_loss improved from 0.20105 to 0.19536, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0045.ckpt
# 27/27 - 6s - loss: 0.1975 - precision: 0.9499 - recall: 0.9499 - f1_score: 0.9552 - false_negatives: 86.0000 - true_positives: 1630.0000 - false_positives: 86.0000 - true_negatives: 1630.0000 - val_loss: 0.1954 - val_precision: 0.9306 - val_recall: 0.9306 - val_f1_score: 0.9378 - val_false_negatives: 5.0000 - val_true_positives: 67.0000 - val_false_positives: 5.0000 - val_true_negatives: 67.0000 - 6s/epoch - 226ms/step
# Epoch 46/200
#
# Epoch 46: val_loss improved from 0.19536 to 0.19092, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0046.ckpt
# 27/27 - 6s - loss: 0.1865 - precision: 0.9516 - recall: 0.9516 - f1_score: 0.9567 - false_negatives: 83.0000 - true_positives: 1633.0000 - false_positives: 83.0000 - true_negatives: 1633.0000 - val_loss: 0.1909 - val_precision: 0.9306 - val_recall: 0.9306 - val_f1_score: 0.9378 - val_false_negatives: 5.0000 - val_true_positives: 67.0000 - val_false_positives: 5.0000 - val_true_negatives: 67.0000 - 6s/epoch - 227ms/step
# Epoch 47/200
#
# Epoch 47: val_loss improved from 0.19092 to 0.18565, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0047.ckpt
# 27/27 - 6s - loss: 0.1842 - precision: 0.9528 - recall: 0.9528 - f1_score: 0.9577 - false_negatives: 81.0000 - true_positives: 1635.0000 - false_positives: 81.0000 - true_negatives: 1635.0000 - val_loss: 0.1856 - val_precision: 0.9306 - val_recall: 0.9306 - val_f1_score: 0.9378 - val_false_negatives: 5.0000 - val_true_positives: 67.0000 - val_false_positives: 5.0000 - val_true_negatives: 67.0000 - 6s/epoch - 227ms/step
# Epoch 48/200
#
# Epoch 48: val_loss improved from 0.18565 to 0.17993, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0048.ckpt
# 27/27 - 6s - loss: 0.1791 - precision: 0.9569 - recall: 0.9569 - f1_score: 0.9609 - false_negatives: 74.0000 - true_positives: 1642.0000 - false_positives: 74.0000 - true_negatives: 1642.0000 - val_loss: 0.1799 - val_precision: 0.9306 - val_recall: 0.9306 - val_f1_score: 0.9378 - val_false_negatives: 5.0000 - val_true_positives: 67.0000 - val_false_positives: 5.0000 - val_true_negatives: 67.0000 - 6s/epoch - 237ms/step
# Epoch 49/200
#
# Epoch 49: val_loss improved from 0.17993 to 0.17622, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0049.ckpt
# 27/27 - 6s - loss: 0.1688 - precision: 0.9621 - recall: 0.9621 - f1_score: 0.9653 - false_negatives: 65.0000 - true_positives: 1651.0000 - false_positives: 65.0000 - true_negatives: 1651.0000 - val_loss: 0.1762 - val_precision: 0.9306 - val_recall: 0.9306 - val_f1_score: 0.9378 - val_false_negatives: 5.0000 - val_true_positives: 67.0000 - val_false_positives: 5.0000 - val_true_negatives: 67.0000 - 6s/epoch - 230ms/step
# Epoch 50/200
#
# Epoch 50: val_loss improved from 0.17622 to 0.16936, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0050.ckpt
# 27/27 - 6s - loss: 0.1588 - precision: 0.9633 - recall: 0.9633 - f1_score: 0.9665 - false_negatives: 63.0000 - true_positives: 1653.0000 - false_positives: 63.0000 - true_negatives: 1653.0000 - val_loss: 0.1694 - val_precision: 0.9444 - val_recall: 0.9444 - val_f1_score: 0.9487 - val_false_negatives: 4.0000 - val_true_positives: 68.0000 - val_false_positives: 4.0000 - val_true_negatives: 68.0000 - 6s/epoch - 229ms/step
# Epoch 51/200
#
# Epoch 51: val_loss improved from 0.16936 to 0.16547, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0051.ckpt
# 27/27 - 6s - loss: 0.1553 - precision: 0.9633 - recall: 0.9633 - f1_score: 0.9665 - false_negatives: 63.0000 - true_positives: 1653.0000 - false_positives: 63.0000 - true_negatives: 1653.0000 - val_loss: 0.1655 - val_precision: 0.9444 - val_recall: 0.9444 - val_f1_score: 0.9487 - val_false_negatives: 4.0000 - val_true_positives: 68.0000 - val_false_positives: 4.0000 - val_true_negatives: 68.0000 - 6s/epoch - 228ms/step
# Epoch 52/200
#
# Epoch 52: val_loss improved from 0.16547 to 0.16155, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0052.ckpt
# 27/27 - 6s - loss: 0.1530 - precision: 0.9610 - recall: 0.9610 - f1_score: 0.9644 - false_negatives: 67.0000 - true_positives: 1649.0000 - false_positives: 67.0000 - true_negatives: 1649.0000 - val_loss: 0.1616 - val_precision: 0.9444 - val_recall: 0.9444 - val_f1_score: 0.9487 - val_false_negatives: 4.0000 - val_true_positives: 68.0000 - val_false_positives: 4.0000 - val_true_negatives: 68.0000 - 6s/epoch - 229ms/step
# Epoch 53/200
#
# Epoch 53: val_loss improved from 0.16155 to 0.15890, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0053.ckpt
# 27/27 - 6s - loss: 0.1517 - precision: 0.9645 - recall: 0.9645 - f1_score: 0.9674 - false_negatives: 61.0000 - true_positives: 1655.0000 - false_positives: 61.0000 - true_negatives: 1655.0000 - val_loss: 0.1589 - val_precision: 0.9444 - val_recall: 0.9444 - val_f1_score: 0.9487 - val_false_negatives: 4.0000 - val_true_positives: 68.0000 - val_false_positives: 4.0000 - val_true_negatives: 68.0000 - 6s/epoch - 225ms/step
# Epoch 54/200
#
# Epoch 54: val_loss improved from 0.15890 to 0.15545, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0054.ckpt
# 27/27 - 6s - loss: 0.1387 - precision: 0.9650 - recall: 0.9650 - f1_score: 0.9679 - false_negatives: 60.0000 - true_positives: 1656.0000 - false_positives: 60.0000 - true_negatives: 1656.0000 - val_loss: 0.1554 - val_precision: 0.9444 - val_recall: 0.9444 - val_f1_score: 0.9487 - val_false_negatives: 4.0000 - val_true_positives: 68.0000 - val_false_positives: 4.0000 - val_true_negatives: 68.0000 - 6s/epoch - 227ms/step
# Epoch 55/200
#
# Epoch 55: val_loss improved from 0.15545 to 0.15209, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0055.ckpt
# 27/27 - 6s - loss: 0.1323 - precision: 0.9714 - recall: 0.9714 - f1_score: 0.9735 - false_negatives: 49.0000 - true_positives: 1667.0000 - false_positives: 49.0000 - true_negatives: 1667.0000 - val_loss: 0.1521 - val_precision: 0.9583 - val_recall: 0.9583 - val_f1_score: 0.9601 - val_false_negatives: 3.0000 - val_true_positives: 69.0000 - val_false_positives: 3.0000 - val_true_negatives: 69.0000 - 6s/epoch - 227ms/step
# Epoch 56/200
#
# Epoch 56: val_loss improved from 0.15209 to 0.14697, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0056.ckpt
# 27/27 - 6s - loss: 0.1292 - precision: 0.9650 - recall: 0.9650 - f1_score: 0.9679 - false_negatives: 60.0000 - true_positives: 1656.0000 - false_positives: 60.0000 - true_negatives: 1656.0000 - val_loss: 0.1470 - val_precision: 0.9583 - val_recall: 0.9583 - val_f1_score: 0.9601 - val_false_negatives: 3.0000 - val_true_positives: 69.0000 - val_false_positives: 3.0000 - val_true_negatives: 69.0000 - 6s/epoch - 226ms/step
# Epoch 57/200
#
# Epoch 57: val_loss improved from 0.14697 to 0.14366, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0057.ckpt
# 27/27 - 6s - loss: 0.1286 - precision: 0.9656 - recall: 0.9656 - f1_score: 0.9684 - false_negatives: 59.0000 - true_positives: 1657.0000 - false_positives: 59.0000 - true_negatives: 1657.0000 - val_loss: 0.1437 - val_precision: 0.9583 - val_recall: 0.9583 - val_f1_score: 0.9601 - val_false_negatives: 3.0000 - val_true_positives: 69.0000 - val_false_positives: 3.0000 - val_true_negatives: 69.0000 - 6s/epoch - 225ms/step
# Epoch 58/200
#
# Epoch 58: val_loss improved from 0.14366 to 0.14144, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0058.ckpt
# 27/27 - 6s - loss: 0.1192 - precision: 0.9679 - recall: 0.9679 - f1_score: 0.9704 - false_negatives: 55.0000 - true_positives: 1661.0000 - false_positives: 55.0000 - true_negatives: 1661.0000 - val_loss: 0.1414 - val_precision: 0.9583 - val_recall: 0.9583 - val_f1_score: 0.9601 - val_false_negatives: 3.0000 - val_true_positives: 69.0000 - val_false_positives: 3.0000 - val_true_negatives: 69.0000 - 6s/epoch - 227ms/step
# Epoch 59/200
#
# Epoch 59: val_loss improved from 0.14144 to 0.13817, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0059.ckpt
# 27/27 - 6s - loss: 0.1112 - precision: 0.9732 - recall: 0.9732 - f1_score: 0.9750 - false_negatives: 46.0000 - true_positives: 1670.0000 - false_positives: 46.0000 - true_negatives: 1670.0000 - val_loss: 0.1382 - val_precision: 0.9583 - val_recall: 0.9583 - val_f1_score: 0.9601 - val_false_negatives: 3.0000 - val_true_positives: 69.0000 - val_false_positives: 3.0000 - val_true_negatives: 69.0000 - 6s/epoch - 235ms/step
# Epoch 60/200
#
# Epoch 60: val_loss improved from 0.13817 to 0.13684, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0060.ckpt
# 27/27 - 6s - loss: 0.1151 - precision: 0.9691 - recall: 0.9691 - f1_score: 0.9714 - false_negatives: 53.0000 - true_positives: 1663.0000 - false_positives: 53.0000 - true_negatives: 1663.0000 - val_loss: 0.1368 - val_precision: 0.9583 - val_recall: 0.9583 - val_f1_score: 0.9601 - val_false_negatives: 3.0000 - val_true_positives: 69.0000 - val_false_positives: 3.0000 - val_true_negatives: 69.0000 - 6s/epoch - 227ms/step
# Epoch 61/200
#
# Epoch 61: val_loss improved from 0.13684 to 0.13425, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0061.ckpt
# 27/27 - 6s - loss: 0.1097 - precision: 0.9726 - recall: 0.9726 - f1_score: 0.9745 - false_negatives: 47.0000 - true_positives: 1669.0000 - false_positives: 47.0000 - true_negatives: 1669.0000 - val_loss: 0.1342 - val_precision: 0.9583 - val_recall: 0.9583 - val_f1_score: 0.9601 - val_false_negatives: 3.0000 - val_true_positives: 69.0000 - val_false_positives: 3.0000 - val_true_negatives: 69.0000 - 6s/epoch - 228ms/step
# Epoch 62/200
#
# Epoch 62: val_loss improved from 0.13425 to 0.13246, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0062.ckpt
# 27/27 - 6s - loss: 0.1068 - precision: 0.9732 - recall: 0.9732 - f1_score: 0.9750 - false_negatives: 46.0000 - true_positives: 1670.0000 - false_positives: 46.0000 - true_negatives: 1670.0000 - val_loss: 0.1325 - val_precision: 0.9583 - val_recall: 0.9583 - val_f1_score: 0.9601 - val_false_negatives: 3.0000 - val_true_positives: 69.0000 - val_false_positives: 3.0000 - val_true_negatives: 69.0000 - 6s/epoch - 227ms/step
# Epoch 63/200
#
# Epoch 63: val_loss did not improve from 0.13246
# 27/27 - 5s - loss: 0.1075 - precision: 0.9732 - recall: 0.9732 - f1_score: 0.9750 - false_negatives: 46.0000 - true_positives: 1670.0000 - false_positives: 46.0000 - true_negatives: 1670.0000 - val_loss: 0.1325 - val_precision: 0.9583 - val_recall: 0.9583 - val_f1_score: 0.9601 - val_false_negatives: 3.0000 - val_true_positives: 69.0000 - val_false_positives: 3.0000 - val_true_negatives: 69.0000 - 5s/epoch - 198ms/step
# Epoch 64/200
#
# Epoch 64: val_loss improved from 0.13246 to 0.12995, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0064.ckpt
# 27/27 - 6s - loss: 0.1023 - precision: 0.9726 - recall: 0.9726 - f1_score: 0.9745 - false_negatives: 47.0000 - true_positives: 1669.0000 - false_positives: 47.0000 - true_negatives: 1669.0000 - val_loss: 0.1300 - val_precision: 0.9583 - val_recall: 0.9583 - val_f1_score: 0.9601 - val_false_negatives: 3.0000 - val_true_positives: 69.0000 - val_false_positives: 3.0000 - val_true_negatives: 69.0000 - 6s/epoch - 232ms/step
# Epoch 65/200
#
# Epoch 65: val_loss improved from 0.12995 to 0.12682, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0065.ckpt
# 27/27 - 6s - loss: 0.0904 - precision: 0.9755 - recall: 0.9755 - f1_score: 0.9770 - false_negatives: 42.0000 - true_positives: 1674.0000 - false_positives: 42.0000 - true_negatives: 1674.0000 - val_loss: 0.1268 - val_precision: 0.9583 - val_recall: 0.9583 - val_f1_score: 0.9601 - val_false_negatives: 3.0000 - val_true_positives: 69.0000 - val_false_positives: 3.0000 - val_true_negatives: 69.0000 - 6s/epoch - 234ms/step
# Epoch 66/200
#
# Epoch 66: val_loss improved from 0.12682 to 0.12465, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0066.ckpt
# 27/27 - 6s - loss: 0.0910 - precision: 0.9749 - recall: 0.9749 - f1_score: 0.9765 - false_negatives: 43.0000 - true_positives: 1673.0000 - false_positives: 43.0000 - true_negatives: 1673.0000 - val_loss: 0.1247 - val_precision: 0.9444 - val_recall: 0.9444 - val_f1_score: 0.9444 - val_false_negatives: 4.0000 - val_true_positives: 68.0000 - val_false_positives: 4.0000 - val_true_negatives: 68.0000 - 6s/epoch - 230ms/step
# Epoch 67/200
#
# Epoch 67: val_loss improved from 0.12465 to 0.12348, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0067.ckpt
# 27/27 - 6s - loss: 0.0906 - precision: 0.9784 - recall: 0.9784 - f1_score: 0.9796 - false_negatives: 37.0000 - true_positives: 1679.0000 - false_positives: 37.0000 - true_negatives: 1679.0000 - val_loss: 0.1235 - val_precision: 0.9583 - val_recall: 0.9583 - val_f1_score: 0.9601 - val_false_negatives: 3.0000 - val_true_positives: 69.0000 - val_false_positives: 3.0000 - val_true_negatives: 69.0000 - 6s/epoch - 225ms/step
# Epoch 68/200
#
# Epoch 68: val_loss improved from 0.12348 to 0.12193, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0068.ckpt
# 27/27 - 6s - loss: 0.0878 - precision: 0.9773 - recall: 0.9773 - f1_score: 0.9786 - false_negatives: 39.0000 - true_positives: 1677.0000 - false_positives: 39.0000 - true_negatives: 1677.0000 - val_loss: 0.1219 - val_precision: 0.9444 - val_recall: 0.9444 - val_f1_score: 0.9444 - val_false_negatives: 4.0000 - val_true_positives: 68.0000 - val_false_positives: 4.0000 - val_true_negatives: 68.0000 - 6s/epoch - 230ms/step
# Epoch 69/200
#
# Epoch 69: val_loss improved from 0.12193 to 0.12037, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0069.ckpt
# 27/27 - 6s - loss: 0.0841 - precision: 0.9755 - recall: 0.9755 - f1_score: 0.9770 - false_negatives: 42.0000 - true_positives: 1674.0000 - false_positives: 42.0000 - true_negatives: 1674.0000 - val_loss: 0.1204 - val_precision: 0.9444 - val_recall: 0.9444 - val_f1_score: 0.9444 - val_false_negatives: 4.0000 - val_true_positives: 68.0000 - val_false_positives: 4.0000 - val_true_negatives: 68.0000 - 6s/epoch - 226ms/step
# Epoch 70/200
#
# Epoch 70: val_loss improved from 0.12037 to 0.11965, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0070.ckpt
# 27/27 - 6s - loss: 0.0805 - precision: 0.9808 - recall: 0.9808 - f1_score: 0.9817 - false_negatives: 33.0000 - true_positives: 1683.0000 - false_positives: 33.0000 - true_negatives: 1683.0000 - val_loss: 0.1197 - val_precision: 0.9444 - val_recall: 0.9444 - val_f1_score: 0.9444 - val_false_negatives: 4.0000 - val_true_positives: 68.0000 - val_false_positives: 4.0000 - val_true_negatives: 68.0000 - 6s/epoch - 240ms/step
# Epoch 71/200
#
# Epoch 71: val_loss improved from 0.11965 to 0.11823, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0071.ckpt
# 27/27 - 6s - loss: 0.0741 - precision: 0.9767 - recall: 0.9767 - f1_score: 0.9781 - false_negatives: 40.0000 - true_positives: 1676.0000 - false_positives: 40.0000 - true_negatives: 1676.0000 - val_loss: 0.1182 - val_precision: 0.9444 - val_recall: 0.9444 - val_f1_score: 0.9444 - val_false_negatives: 4.0000 - val_true_positives: 68.0000 - val_false_positives: 4.0000 - val_true_negatives: 68.0000 - 6s/epoch - 231ms/step
# Epoch 72/200
#
# Epoch 72: val_loss improved from 0.11823 to 0.11705, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0072.ckpt
# 27/27 - 6s - loss: 0.0698 - precision: 0.9808 - recall: 0.9808 - f1_score: 0.9817 - false_negatives: 33.0000 - true_positives: 1683.0000 - false_positives: 33.0000 - true_negatives: 1683.0000 - val_loss: 0.1170 - val_precision: 0.9444 - val_recall: 0.9444 - val_f1_score: 0.9444 - val_false_negatives: 4.0000 - val_true_positives: 68.0000 - val_false_positives: 4.0000 - val_true_negatives: 68.0000 - 6s/epoch - 226ms/step
# Epoch 73/200
#
# Epoch 73: val_loss improved from 0.11705 to 0.11558, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0073.ckpt
# 27/27 - 6s - loss: 0.0700 - precision: 0.9808 - recall: 0.9808 - f1_score: 0.9817 - false_negatives: 33.0000 - true_positives: 1683.0000 - false_positives: 33.0000 - true_negatives: 1683.0000 - val_loss: 0.1156 - val_precision: 0.9444 - val_recall: 0.9444 - val_f1_score: 0.9444 - val_false_negatives: 4.0000 - val_true_positives: 68.0000 - val_false_positives: 4.0000 - val_true_negatives: 68.0000 - 6s/epoch - 231ms/step
# Epoch 74/200
#
# Epoch 74: val_loss improved from 0.11558 to 0.11497, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0074.ckpt
# 27/27 - 6s - loss: 0.0707 - precision: 0.9773 - recall: 0.9773 - f1_score: 0.9786 - false_negatives: 39.0000 - true_positives: 1677.0000 - false_positives: 39.0000 - true_negatives: 1677.0000 - val_loss: 0.1150 - val_precision: 0.9444 - val_recall: 0.9444 - val_f1_score: 0.9444 - val_false_negatives: 4.0000 - val_true_positives: 68.0000 - val_false_positives: 4.0000 - val_true_negatives: 68.0000 - 6s/epoch - 230ms/step
# Epoch 75/200
#
# Epoch 75: val_loss improved from 0.11497 to 0.11409, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0075.ckpt
# 27/27 - 6s - loss: 0.0668 - precision: 0.9808 - recall: 0.9808 - f1_score: 0.9817 - false_negatives: 33.0000 - true_positives: 1683.0000 - false_positives: 33.0000 - true_negatives: 1683.0000 - val_loss: 0.1141 - val_precision: 0.9444 - val_recall: 0.9444 - val_f1_score: 0.9444 - val_false_negatives: 4.0000 - val_true_positives: 68.0000 - val_false_positives: 4.0000 - val_true_negatives: 68.0000 - 6s/epoch - 231ms/step
# Epoch 76/200
#
# Epoch 76: val_loss improved from 0.11409 to 0.11327, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0076.ckpt
# 27/27 - 6s - loss: 0.0661 - precision: 0.9825 - recall: 0.9825 - f1_score: 0.9833 - false_negatives: 30.0000 - true_positives: 1686.0000 - false_positives: 30.0000 - true_negatives: 1686.0000 - val_loss: 0.1133 - val_precision: 0.9444 - val_recall: 0.9444 - val_f1_score: 0.9444 - val_false_negatives: 4.0000 - val_true_positives: 68.0000 - val_false_positives: 4.0000 - val_true_negatives: 68.0000 - 6s/epoch - 226ms/step
# Epoch 77/200
#
# Epoch 77: val_loss improved from 0.11327 to 0.11307, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0077.ckpt
# 27/27 - 6s - loss: 0.0661 - precision: 0.9819 - recall: 0.9819 - f1_score: 0.9828 - false_negatives: 31.0000 - true_positives: 1685.0000 - false_positives: 31.0000 - true_negatives: 1685.0000 - val_loss: 0.1131 - val_precision: 0.9444 - val_recall: 0.9444 - val_f1_score: 0.9444 - val_false_negatives: 4.0000 - val_true_positives: 68.0000 - val_false_positives: 4.0000 - val_true_negatives: 68.0000 - 6s/epoch - 230ms/step
# Epoch 78/200
#
# Epoch 78: val_loss improved from 0.11307 to 0.11253, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0078.ckpt
# 27/27 - 6s - loss: 0.0639 - precision: 0.9831 - recall: 0.9831 - f1_score: 0.9839 - false_negatives: 29.0000 - true_positives: 1687.0000 - false_positives: 29.0000 - true_negatives: 1687.0000 - val_loss: 0.1125 - val_precision: 0.9444 - val_recall: 0.9444 - val_f1_score: 0.9444 - val_false_negatives: 4.0000 - val_true_positives: 68.0000 - val_false_positives: 4.0000 - val_true_negatives: 68.0000 - 6s/epoch - 230ms/step
# Epoch 79/200
#
# Epoch 79: val_loss improved from 0.11253 to 0.11180, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0079.ckpt
# 27/27 - 6s - loss: 0.0584 - precision: 0.9843 - recall: 0.9843 - f1_score: 0.9849 - false_negatives: 27.0000 - true_positives: 1689.0000 - false_positives: 27.0000 - true_negatives: 1689.0000 - val_loss: 0.1118 - val_precision: 0.9444 - val_recall: 0.9444 - val_f1_score: 0.9444 - val_false_negatives: 4.0000 - val_true_positives: 68.0000 - val_false_positives: 4.0000 - val_true_negatives: 68.0000 - 6s/epoch - 228ms/step
# Epoch 80/200
#
# Epoch 80: val_loss improved from 0.11180 to 0.11116, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0080.ckpt
# 27/27 - 6s - loss: 0.0547 - precision: 0.9854 - recall: 0.9854 - f1_score: 0.9860 - false_negatives: 25.0000 - true_positives: 1691.0000 - false_positives: 25.0000 - true_negatives: 1691.0000 - val_loss: 0.1112 - val_precision: 0.9444 - val_recall: 0.9444 - val_f1_score: 0.9444 - val_false_negatives: 4.0000 - val_true_positives: 68.0000 - val_false_positives: 4.0000 - val_true_negatives: 68.0000 - 6s/epoch - 228ms/step
# Epoch 81/200
#
# Epoch 81: val_loss improved from 0.11116 to 0.11098, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0081.ckpt
# 27/27 - 6s - loss: 0.0553 - precision: 0.9854 - recall: 0.9854 - f1_score: 0.9860 - false_negatives: 25.0000 - true_positives: 1691.0000 - false_positives: 25.0000 - true_negatives: 1691.0000 - val_loss: 0.1110 - val_precision: 0.9444 - val_recall: 0.9444 - val_f1_score: 0.9444 - val_false_negatives: 4.0000 - val_true_positives: 68.0000 - val_false_positives: 4.0000 - val_true_negatives: 68.0000 - 6s/epoch - 239ms/step
# Epoch 82/200
#
# Epoch 82: val_loss improved from 0.11098 to 0.11035, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0082.ckpt
# 27/27 - 6s - loss: 0.0537 - precision: 0.9848 - recall: 0.9848 - f1_score: 0.9855 - false_negatives: 26.0000 - true_positives: 1690.0000 - false_positives: 26.0000 - true_negatives: 1690.0000 - val_loss: 0.1104 - val_precision: 0.9444 - val_recall: 0.9444 - val_f1_score: 0.9444 - val_false_negatives: 4.0000 - val_true_positives: 68.0000 - val_false_positives: 4.0000 - val_true_negatives: 68.0000 - 6s/epoch - 229ms/step
# Epoch 83/200
#
# Epoch 83: val_loss improved from 0.11035 to 0.11030, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0083.ckpt
# 27/27 - 6s - loss: 0.0524 - precision: 0.9854 - recall: 0.9854 - f1_score: 0.9860 - false_negatives: 25.0000 - true_positives: 1691.0000 - false_positives: 25.0000 - true_negatives: 1691.0000 - val_loss: 0.1103 - val_precision: 0.9444 - val_recall: 0.9444 - val_f1_score: 0.9444 - val_false_negatives: 4.0000 - val_true_positives: 68.0000 - val_false_positives: 4.0000 - val_true_negatives: 68.0000 - 6s/epoch - 228ms/step
# Epoch 84/200
#
# Epoch 84: val_loss improved from 0.11030 to 0.10983, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0084.ckpt
# 27/27 - 6s - loss: 0.0520 - precision: 0.9843 - recall: 0.9843 - f1_score: 0.9849 - false_negatives: 27.0000 - true_positives: 1689.0000 - false_positives: 27.0000 - true_negatives: 1689.0000 - val_loss: 0.1098 - val_precision: 0.9444 - val_recall: 0.9444 - val_f1_score: 0.9444 - val_false_negatives: 4.0000 - val_true_positives: 68.0000 - val_false_positives: 4.0000 - val_true_negatives: 68.0000 - 6s/epoch - 230ms/step
# Epoch 85/200
#
# Epoch 85: val_loss improved from 0.10983 to 0.10973, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0085.ckpt
# 27/27 - 6s - loss: 0.0486 - precision: 0.9866 - recall: 0.9866 - f1_score: 0.9871 - false_negatives: 23.0000 - true_positives: 1693.0000 - false_positives: 23.0000 - true_negatives: 1693.0000 - val_loss: 0.1097 - val_precision: 0.9444 - val_recall: 0.9444 - val_f1_score: 0.9444 - val_false_negatives: 4.0000 - val_true_positives: 68.0000 - val_false_positives: 4.0000 - val_true_negatives: 68.0000 - 6s/epoch - 228ms/step
# Epoch 86/200
#
# Epoch 86: val_loss improved from 0.10973 to 0.10940, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0086.ckpt
# 27/27 - 6s - loss: 0.0452 - precision: 0.9860 - recall: 0.9860 - f1_score: 0.9865 - false_negatives: 24.0000 - true_positives: 1692.0000 - false_positives: 24.0000 - true_negatives: 1692.0000 - val_loss: 0.1094 - val_precision: 0.9444 - val_recall: 0.9444 - val_f1_score: 0.9444 - val_false_negatives: 4.0000 - val_true_positives: 68.0000 - val_false_positives: 4.0000 - val_true_negatives: 68.0000 - 6s/epoch - 226ms/step
# Epoch 87/200
#
# Epoch 87: val_loss improved from 0.10940 to 0.10924, saving model to checkpoints/efficientnetv2-b0/fold_1/cp-0087.ckpt
# ...
# Epoch 172/200
#
# Epoch 172: val_loss improved from 0.00004 to 0.00004, saving model to checkpoints/efficientnetv2-b0/fold_5/cp-0172.ckpt
# 27/27 - 7s - loss: 2.4712e-04 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - false_negatives: 0.0000e+00 - true_positives: 1722.0000 - false_positives: 0.0000e+00 - true_negatives: 1722.0000 - val_loss: 3.7865e-05 - val_precision: 1.0000 - val_recall: 1.0000 - val_f1_score: 1.0000 - val_false_negatives: 0.0000e+00 - val_true_positives: 71.0000 - val_false_positives: 0.0000e+00 - val_true_negatives: 71.0000 - 7s/epoch - 250ms/step
# Epoch 173/200
#
# Epoch 173: val_loss improved from 0.00004 to 0.00004, saving model to checkpoints/efficientnetv2-b0/fold_5/cp-0173.ckpt
# 27/27 - 6s - loss: 2.6587e-04 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - false_negatives: 0.0000e+00 - true_positives: 1722.0000 - false_positives: 0.0000e+00 - true_negatives: 1722.0000 - val_loss: 3.7455e-05 - val_precision: 1.0000 - val_recall: 1.0000 - val_f1_score: 1.0000 - val_false_negatives: 0.0000e+00 - val_true_positives: 71.0000 - val_false_positives: 0.0000e+00 - val_true_negatives: 71.0000 - 6s/epoch - 225ms/step
# Epoch 174/200
#
# Epoch 174: val_loss improved from 0.00004 to 0.00004, saving model to checkpoints/efficientnetv2-b0/fold_5/cp-0174.ckpt
# 27/27 - 6s - loss: 3.0091e-04 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - false_negatives: 0.0000e+00 - true_positives: 1722.0000 - false_positives: 0.0000e+00 - true_negatives: 1722.0000 - val_loss: 3.6714e-05 - val_precision: 1.0000 - val_recall: 1.0000 - val_f1_score: 1.0000 - val_false_negatives: 0.0000e+00 - val_true_positives: 71.0000 - val_false_positives: 0.0000e+00 - val_true_negatives: 71.0000 - 6s/epoch - 225ms/step
# Epoch 175/200
#
# Epoch 175: val_loss did not improve from 0.00004
# 27/27 - 5s - loss: 5.1563e-04 - precision: 0.9994 - recall: 0.9994 - f1_score: 0.9994 - false_negatives: 1.0000 - true_positives: 1721.0000 - false_positives: 1.0000 - true_negatives: 1721.0000 - val_loss: 3.8224e-05 - val_precision: 1.0000 - val_recall: 1.0000 - val_f1_score: 1.0000 - val_false_negatives: 0.0000e+00 - val_true_positives: 71.0000 - val_false_positives: 0.0000e+00 - val_true_negatives: 71.0000 - 5s/epoch - 194ms/step
# Epoch 176/200
#
# Epoch 176: val_loss did not improve from 0.00004
# 27/27 - 5s - loss: 2.3565e-04 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - false_negatives: 0.0000e+00 - true_positives: 1722.0000 - false_positives: 0.0000e+00 - true_negatives: 1722.0000 - val_loss: 3.7455e-05 - val_precision: 1.0000 - val_recall: 1.0000 - val_f1_score: 1.0000 - val_false_negatives: 0.0000e+00 - val_true_positives: 71.0000 - val_false_positives: 0.0000e+00 - val_true_negatives: 71.0000 - 5s/epoch - 192ms/step
# Epoch 177/200
#
# Epoch 177: val_loss improved from 0.00004 to 0.00004, saving model to checkpoints/efficientnetv2-b0/fold_5/cp-0177.ckpt
# 27/27 - 6s - loss: 2.3691e-04 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - false_negatives: 0.0000e+00 - true_positives: 1722.0000 - false_positives: 0.0000e+00 - true_negatives: 1722.0000 - val_loss: 3.5767e-05 - val_precision: 1.0000 - val_recall: 1.0000 - val_f1_score: 1.0000 - val_false_negatives: 0.0000e+00 - val_true_positives: 71.0000 - val_false_positives: 0.0000e+00 - val_true_negatives: 71.0000 - 6s/epoch - 227ms/step
# Epoch 178/200
#
# Epoch 178: val_loss improved from 0.00004 to 0.00003, saving model to checkpoints/efficientnetv2-b0/fold_5/cp-0178.ckpt
# 27/27 - 6s - loss: 3.1249e-04 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - false_negatives: 0.0000e+00 - true_positives: 1722.0000 - false_positives: 0.0000e+00 - true_negatives: 1722.0000 - val_loss: 3.3867e-05 - val_precision: 1.0000 - val_recall: 1.0000 - val_f1_score: 1.0000 - val_false_negatives: 0.0000e+00 - val_true_positives: 71.0000 - val_false_positives: 0.0000e+00 - val_true_negatives: 71.0000 - 6s/epoch - 230ms/step
# Epoch 179/200
#
# Epoch 179: val_loss improved from 0.00003 to 0.00003, saving model to checkpoints/efficientnetv2-b0/fold_5/cp-0179.ckpt
# 27/27 - 6s - loss: 4.2600e-04 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - false_negatives: 0.0000e+00 - true_positives: 1722.0000 - false_positives: 0.0000e+00 - true_negatives: 1722.0000 - val_loss: 3.3798e-05 - val_precision: 1.0000 - val_recall: 1.0000 - val_f1_score: 1.0000 - val_false_negatives: 0.0000e+00 - val_true_positives: 71.0000 - val_false_positives: 0.0000e+00 - val_true_negatives: 71.0000 - 6s/epoch - 223ms/step
# Epoch 180/200
#
# Epoch 180: val_loss improved from 0.00003 to 0.00003, saving model to checkpoints/efficientnetv2-b0/fold_5/cp-0180.ckpt
# 27/27 - 6s - loss: 3.6954e-04 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - false_negatives: 0.0000e+00 - true_positives: 1722.0000 - false_positives: 0.0000e+00 - true_negatives: 1722.0000 - val_loss: 3.2484e-05 - val_precision: 1.0000 - val_recall: 1.0000 - val_f1_score: 1.0000 - val_false_negatives: 0.0000e+00 - val_true_positives: 71.0000 - val_false_positives: 0.0000e+00 - val_true_negatives: 71.0000 - 6s/epoch - 226ms/step
# Epoch 181/200
#
# Epoch 181: val_loss improved from 0.00003 to 0.00003, saving model to checkpoints/efficientnetv2-b0/fold_5/cp-0181.ckpt
# 27/27 - 6s - loss: 1.6833e-04 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - false_negatives: 0.0000e+00 - true_positives: 1722.0000 - false_positives: 0.0000e+00 - true_negatives: 1722.0000 - val_loss: 3.2175e-05 - val_precision: 1.0000 - val_recall: 1.0000 - val_f1_score: 1.0000 - val_false_negatives: 0.0000e+00 - val_true_positives: 71.0000 - val_false_positives: 0.0000e+00 - val_true_negatives: 71.0000 - 6s/epoch - 228ms/step
# Epoch 182/200
#
# Epoch 182: val_loss improved from 0.00003 to 0.00003, saving model to checkpoints/efficientnetv2-b0/fold_5/cp-0182.ckpt
# 27/27 - 6s - loss: 2.1608e-04 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - false_negatives: 0.0000e+00 - true_positives: 1722.0000 - false_positives: 0.0000e+00 - true_negatives: 1722.0000 - val_loss: 3.1627e-05 - val_precision: 1.0000 - val_recall: 1.0000 - val_f1_score: 1.0000 - val_false_negatives: 0.0000e+00 - val_true_positives: 71.0000 - val_false_positives: 0.0000e+00 - val_true_negatives: 71.0000 - 6s/epoch - 225ms/step
# Epoch 183/200
#
# Epoch 183: val_loss improved from 0.00003 to 0.00003, saving model to checkpoints/efficientnetv2-b0/fold_5/cp-0183.ckpt
# 27/27 - 6s - loss: 1.5709e-04 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - false_negatives: 0.0000e+00 - true_positives: 1722.0000 - false_positives: 0.0000e+00 - true_negatives: 1722.0000 - val_loss: 3.1546e-05 - val_precision: 1.0000 - val_recall: 1.0000 - val_f1_score: 1.0000 - val_false_negatives: 0.0000e+00 - val_true_positives: 71.0000 - val_false_positives: 0.0000e+00 - val_true_negatives: 71.0000 - 6s/epoch - 228ms/step
# Epoch 184/200
#
# Epoch 184: val_loss improved from 0.00003 to 0.00003, saving model to checkpoints/efficientnetv2-b0/fold_5/cp-0184.ckpt
# 27/27 - 6s - loss: 2.4123e-04 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - false_negatives: 0.0000e+00 - true_positives: 1722.0000 - false_positives: 0.0000e+00 - true_negatives: 1722.0000 - val_loss: 3.0244e-05 - val_precision: 1.0000 - val_recall: 1.0000 - val_f1_score: 1.0000 - val_false_negatives: 0.0000e+00 - val_true_positives: 71.0000 - val_false_positives: 0.0000e+00 - val_true_negatives: 71.0000 - 6s/epoch - 230ms/step
# Epoch 185/200
#
# Epoch 185: val_loss improved from 0.00003 to 0.00003, saving model to checkpoints/efficientnetv2-b0/fold_5/cp-0185.ckpt
# 27/27 - 6s - loss: 1.8201e-04 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - false_negatives: 0.0000e+00 - true_positives: 1722.0000 - false_positives: 0.0000e+00 - true_negatives: 1722.0000 - val_loss: 2.9490e-05 - val_precision: 1.0000 - val_recall: 1.0000 - val_f1_score: 1.0000 - val_false_negatives: 0.0000e+00 - val_true_positives: 71.0000 - val_false_positives: 0.0000e+00 - val_true_negatives: 71.0000 - 6s/epoch - 227ms/step
# Epoch 186/200
#
# Epoch 186: val_loss improved from 0.00003 to 0.00003, saving model to checkpoints/efficientnetv2-b0/fold_5/cp-0186.ckpt
# 27/27 - 6s - loss: 2.7066e-04 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - false_negatives: 0.0000e+00 - true_positives: 1722.0000 - false_positives: 0.0000e+00 - true_negatives: 1722.0000 - val_loss: 2.9179e-05 - val_precision: 1.0000 - val_recall: 1.0000 - val_f1_score: 1.0000 - val_false_negatives: 0.0000e+00 - val_true_positives: 71.0000 - val_false_positives: 0.0000e+00 - val_true_negatives: 71.0000 - 6s/epoch - 226ms/step
# Epoch 187/200
#
# Epoch 187: val_loss did not improve from 0.00003
# 27/27 - 5s - loss: 2.5159e-04 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - false_negatives: 0.0000e+00 - true_positives: 1722.0000 - false_positives: 0.0000e+00 - true_negatives: 1722.0000 - val_loss: 2.9784e-05 - val_precision: 1.0000 - val_recall: 1.0000 - val_f1_score: 1.0000 - val_false_negatives: 0.0000e+00 - val_true_positives: 71.0000 - val_false_positives: 0.0000e+00 - val_true_negatives: 71.0000 - 5s/epoch - 193ms/step
# Epoch 188/200
#
# Epoch 188: val_loss did not improve from 0.00003
# 27/27 - 5s - loss: 2.1600e-04 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - false_negatives: 0.0000e+00 - true_positives: 1722.0000 - false_positives: 0.0000e+00 - true_negatives: 1722.0000 - val_loss: 2.9605e-05 - val_precision: 1.0000 - val_recall: 1.0000 - val_f1_score: 1.0000 - val_false_negatives: 0.0000e+00 - val_true_positives: 71.0000 - val_false_positives: 0.0000e+00 - val_true_negatives: 71.0000 - 5s/epoch - 194ms/step
# Epoch 189/200
#
# Epoch 189: val_loss did not improve from 0.00003
# 27/27 - 5s - loss: 1.8027e-04 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - false_negatives: 0.0000e+00 - true_positives: 1722.0000 - false_positives: 0.0000e+00 - true_negatives: 1722.0000 - val_loss: 2.9232e-05 - val_precision: 1.0000 - val_recall: 1.0000 - val_f1_score: 1.0000 - val_false_negatives: 0.0000e+00 - val_true_positives: 71.0000 - val_false_positives: 0.0000e+00 - val_true_negatives: 71.0000 - 5s/epoch - 194ms/step
# Epoch 190/200
#
# Epoch 190: val_loss improved from 0.00003 to 0.00003, saving model to checkpoints/efficientnetv2-b0/fold_5/cp-0190.ckpt
# 27/27 - 6s - loss: 1.7931e-04 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - false_negatives: 0.0000e+00 - true_positives: 1722.0000 - false_positives: 0.0000e+00 - true_negatives: 1722.0000 - val_loss: 2.8160e-05 - val_precision: 1.0000 - val_recall: 1.0000 - val_f1_score: 1.0000 - val_false_negatives: 0.0000e+00 - val_true_positives: 71.0000 - val_false_positives: 0.0000e+00 - val_true_negatives: 71.0000 - 6s/epoch - 228ms/step
# Epoch 191/200
#
# Epoch 191: val_loss did not improve from 0.00003
# 27/27 - 5s - loss: 2.5050e-04 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - false_negatives: 0.0000e+00 - true_positives: 1722.0000 - false_positives: 0.0000e+00 - true_negatives: 1722.0000 - val_loss: 2.8215e-05 - val_precision: 1.0000 - val_recall: 1.0000 - val_f1_score: 1.0000 - val_false_negatives: 0.0000e+00 - val_true_positives: 71.0000 - val_false_positives: 0.0000e+00 - val_true_negatives: 71.0000 - 5s/epoch - 194ms/step
# Epoch 192/200
#
# Epoch 192: val_loss did not improve from 0.00003
# 27/27 - 5s - loss: 4.1413e-04 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - false_negatives: 0.0000e+00 - true_positives: 1722.0000 - false_positives: 0.0000e+00 - true_negatives: 1722.0000 - val_loss: 3.4663e-05 - val_precision: 1.0000 - val_recall: 1.0000 - val_f1_score: 1.0000 - val_false_negatives: 0.0000e+00 - val_true_positives: 71.0000 - val_false_positives: 0.0000e+00 - val_true_negatives: 71.0000 - 5s/epoch - 193ms/step
# Epoch 193/200
#
# Epoch 193: val_loss did not improve from 0.00003
# 27/27 - 5s - loss: 1.9263e-04 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - false_negatives: 0.0000e+00 - true_positives: 1722.0000 - false_positives: 0.0000e+00 - true_negatives: 1722.0000 - val_loss: 3.3683e-05 - val_precision: 1.0000 - val_recall: 1.0000 - val_f1_score: 1.0000 - val_false_negatives: 0.0000e+00 - val_true_positives: 71.0000 - val_false_positives: 0.0000e+00 - val_true_negatives: 71.0000 - 5s/epoch - 192ms/step
# Epoch 194/200
#
# Epoch 194: val_loss did not improve from 0.00003
# 27/27 - 5s - loss: 2.9143e-04 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - false_negatives: 0.0000e+00 - true_positives: 1722.0000 - false_positives: 0.0000e+00 - true_negatives: 1722.0000 - val_loss: 3.2370e-05 - val_precision: 1.0000 - val_recall: 1.0000 - val_f1_score: 1.0000 - val_false_negatives: 0.0000e+00 - val_true_positives: 71.0000 - val_false_positives: 0.0000e+00 - val_true_negatives: 71.0000 - 5s/epoch - 195ms/step
# Epoch 195/200
#
# Epoch 195: val_loss did not improve from 0.00003
# 27/27 - 5s - loss: 2.8222e-04 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - false_negatives: 0.0000e+00 - true_positives: 1722.0000 - false_positives: 0.0000e+00 - true_negatives: 1722.0000 - val_loss: 3.4279e-05 - val_precision: 1.0000 - val_recall: 1.0000 - val_f1_score: 1.0000 - val_false_negatives: 0.0000e+00 - val_true_positives: 71.0000 - val_false_positives: 0.0000e+00 - val_true_negatives: 71.0000 - 5s/epoch - 193ms/step
# Epoch 196/200
#
# Epoch 196: val_loss did not improve from 0.00003
# 27/27 - 5s - loss: 1.4574e-04 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - false_negatives: 0.0000e+00 - true_positives: 1722.0000 - false_positives: 0.0000e+00 - true_negatives: 1722.0000 - val_loss: 4.7245e-05 - val_precision: 1.0000 - val_recall: 1.0000 - val_f1_score: 1.0000 - val_false_negatives: 0.0000e+00 - val_true_positives: 71.0000 - val_false_positives: 0.0000e+00 - val_true_negatives: 71.0000 - 5s/epoch - 193ms/step
# Epoch 197/200
#
# Epoch 197: val_loss did not improve from 0.00003
# 27/27 - 5s - loss: 2.4077e-04 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - false_negatives: 0.0000e+00 - true_positives: 1722.0000 - false_positives: 0.0000e+00 - true_negatives: 1722.0000 - val_loss: 4.4658e-05 - val_precision: 1.0000 - val_recall: 1.0000 - val_f1_score: 1.0000 - val_false_negatives: 0.0000e+00 - val_true_positives: 71.0000 - val_false_positives: 0.0000e+00 - val_true_negatives: 71.0000 - 5s/epoch - 194ms/step
# Epoch 198/200
#
# Epoch 198: val_loss did not improve from 0.00003
# 27/27 - 5s - loss: 1.2043e-04 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - false_negatives: 0.0000e+00 - true_positives: 1722.0000 - false_positives: 0.0000e+00 - true_negatives: 1722.0000 - val_loss: 4.0958e-05 - val_precision: 1.0000 - val_recall: 1.0000 - val_f1_score: 1.0000 - val_false_negatives: 0.0000e+00 - val_true_positives: 71.0000 - val_false_positives: 0.0000e+00 - val_true_negatives: 71.0000 - 5s/epoch - 195ms/step
# Epoch 199/200
#
# Epoch 199: val_loss did not improve from 0.00003
# 27/27 - 5s - loss: 1.7477e-04 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - false_negatives: 0.0000e+00 - true_positives: 1722.0000 - false_positives: 0.0000e+00 - true_negatives: 1722.0000 - val_loss: 3.7892e-05 - val_precision: 1.0000 - val_recall: 1.0000 - val_f1_score: 1.0000 - val_false_negatives: 0.0000e+00 - val_true_positives: 71.0000 - val_false_positives: 0.0000e+00 - val_true_negatives: 71.0000 - 5s/epoch - 192ms/step
# Epoch 200/200
#
# Epoch 200: val_loss did not improve from 0.00003
# 27/27 - 5s - loss: 1.2184e-04 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - false_negatives: 0.0000e+00 - true_positives: 1722.0000 - false_positives: 0.0000e+00 - true_negatives: 1722.0000 - val_loss: 3.6105e-05 - val_precision: 1.0000 - val_recall: 1.0000 - val_f1_score: 1.0000 - val_false_negatives: 0.0000e+00 - val_true_positives: 71.0000 - val_false_positives: 0.0000e+00 - val_true_negatives: 71.0000 - 5s/epoch - 193ms/step
